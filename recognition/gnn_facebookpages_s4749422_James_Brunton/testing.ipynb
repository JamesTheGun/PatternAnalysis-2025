# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import os
#this is where your repo is, will work better later but for now is hacky
os.chdir(r"C:\Users\jamed\OneDrive\Desktop\patterns_final\PatternAnalysis-2025")

# %%
from recognition.gnn_facebookpages_s4749422_James_Brunton.dataset import _load_edges, _load_features, _load_targets

# %%
edges = _load_edges() # <- how the pages are linked...
targets = _load_targets() #y <- what catagory the page is...
features = _load_features() #X <- list of each pages token IDs ... I.E., the encoded words of that page.
print(features.head())
print(targets.head())
print(edges.head())
print("-------")
print(targets["page_type"].value_counts())
# Out:
# 554      [2835, 4518, 2198, 2014, 3818, 3045, 4570, 458...
# 10772                        [3293, 2534, 979, 2014, 2317]
# 6350                   [4477, 2895, 4039, 3282, 765, 2669]
# 9218     [3133, 2052, 979, 3355, 107, 1878, 1105, 4571,...
# 7787     [1151, 631, 2613, 2791, 648, 1684, 3818, 107, ...
# dtype: object
#    id       facebook_id                                     page_name  \
# 0   0   145647315578475                      The Voice of China 中国好声音
# 1   1      191483281412                 U.S. Consulate General Mumbai
# 2   2   144761358898518                                          ESET
# 3   3   568700043198473  Consulate General of Switzerland in Montreal
# 4   4  1408935539376139             Mark Bailey MP - Labor for Miller
#
#     page_type
# 0      tvshow
# 1  government
# 2     company
# 3  government
# 4  politician
#    id_1   id_2
# 0     0  18427
# 1     1  21708
# 2     1  22208
# 3     1  22171
# 4     1   6829
# -------
# page_type
# government    6880
# ...

# %%
from recognition.gnn_facebookpages_s4749422_James_Brunton.train import main
main()
# Out:
# TEST ACCURACY: 0.318
# UMAP not installed; skipping UMAP plot.

# %%
from recognition.gnn_facebookpages_s4749422_James_Brunton.predict import main
main()
# Out:
# C:\Users\jamed\OneDrive\Desktop\patterns_final\PatternAnalysis-2025\recognition\gnn_facebookpages_s4749422_James_Brunton\predict.py:23: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental 
# ...

# %%
targets[targets["id"] == 3838]
# Out:
#         id   facebook_id         page_name   page_type
# 3838  3838  324823886818  Stephen Jones MP  politician
