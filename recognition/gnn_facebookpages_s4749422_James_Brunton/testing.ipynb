# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
#this is where your repo is, will work better later but for now is hacky
os.chdir(r"C:\Users\jamed\OneDrive\Desktop\patterns_final\PatternAnalysis-2025")

# %%
from recognition.gnn_facebookpages_s4749422_James_Brunton.dataset import _load_edges, _load_features, _load_targets

# %%
edges = _load_edges() # <- how the pages are linked...
targets = _load_targets() #y <- what catagory the page is...
features = _load_features() #X <- list of each pages token IDs ... I.E., the encoded words of that page.
print(features.head())
print(targets.head())
print(edges.head())
# Out:
# 554      [2835, 4518, 2198, 2014, 3818, 3045, 4570, 458...
# 10772                        [3293, 2534, 979, 2014, 2317]
# 6350                   [4477, 2895, 4039, 3282, 765, 2669]
# 9218     [3133, 2052, 979, 3355, 107, 1878, 1105, 4571,...
# 7787     [1151, 631, 2613, 2791, 648, 1684, 3818, 107, ...
# dtype: object
#    id       facebook_id                                     page_name  \
# 0   0   145647315578475                      The Voice of China 中国好声音
# 1   1      191483281412                 U.S. Consulate General Mumbai
# 2   2   144761358898518                                          ESET
# 3   3   568700043198473  Consulate General of Switzerland in Montreal
# 4   4  1408935539376139             Mark Bailey MP - Labor for Miller
#
#     page_type
# 0      tvshow
# 1  government
# 2     company
# 3  government
# 4  politician
#    id_1   id_2
# 0     0  18427
# 1     1  21708
# 2     1  22208
# 3     1  22171
# 4     1   6829

# %%
from recognition.gnn_facebookpages_s4749422_James_Brunton.predict import main
main()
# Out:
# [020] loss=1.2760 val_acc=0.346
# [040] loss=1.1405 val_acc=0.404
# [060] loss=1.1067 val_acc=0.378
# [080] loss=1.0914 val_acc=0.368
# [100] loss=1.0578 val_acc=0.384
# [120] loss=1.1273 val_acc=0.424
# [140] loss=0.9788 val_acc=0.392
# [160] loss=1.0821 val_acc=0.414
# [180] loss=1.0186 val_acc=0.402
# TEST ACC: 0.734
# saved gcn_checkpoint.pt
#
# Node 554:
#   politician: 0.454
#   government: 0.192
#   company: 0.177
#
# Node 9218:
#   government: 0.891
#   politician: 0.036
#   company: 0.036
#
# Node 10772:
#   government: 0.802
#   politician: 0.066
#   company: 0.066
#
# Node 9283:
#   tvshow: 0.479
#   government: 0.174
#   company: 0.174
#
# Node 3324:
#   company: 0.507
#   politician: 0.164
#   government: 0.164
#
# Node 1111:
#   politician: 0.899
#   government: 0.034
#   company: 0.034
#
# Node 123:
#   government: 0.790
#   politician: 0.070
#   company: 0.070
#
# Node 9217:
#   company: 0.910
#   politician: 0.030
#   government: 0.030

# %%
targets[targets["id"] == 554]
# Out:
#       id  facebook_id     page_name   page_type
# 554  554  10128918116  Gavin Newsom  politician
